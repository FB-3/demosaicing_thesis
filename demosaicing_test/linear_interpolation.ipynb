# %% [markdown]
# # Interpolazione Lineare
#
# L'interpolazione lineare si basa sull'idea che il cambiamento tra due punti
# noti possa essere approssimato da una linea retta, che viene utilizzata per stimare i valori intermedi.
#
# In Python l'interpolazione lineare è presente nella libreria $\verb|scipy.interpolate|$.
#
# ## Kodak Dataset
#
# Le immagini utilizzate sono state prese dal dataset di immagini RAW Kodak (.PCD):
#
# > https://www.math.purdue.edu/~lucier/PHOTO_CD/

# %%
# Loading Kodak Image Dataset

import numpy as np
import pandas
import imageio.v2 as imageio
import matplotlib.pyplot as plt

data_images = pandas.read_csv('dataset.csv')
image_list = []

for i in range(data_images.shape[0]):
    pcd_images = imageio.imread(data_images.loc[i, 'image_path'], format = 'PCD')
    image_list.append(pcd_images)

# Errori nella lettura: FILE [3], [8], [9], [16], [17], [18]

# %%
import numpy as np
from scipy.interpolate import griddata

def linear_interpolation(A, m, n):

    grid_x, grid_y = np.meshgrid(np.linspace(0, m-1, m), np.linspace(0, n-1, n), indexing = 'ij')

    n, m = A.shape
    A = A.flatten()

    nan_indices = np.isnan(A) 
    known_indices = ~nan_indices
    known_list = np.flatnonzero(known_indices)

    kr, kc = np.unravel_index(known_list, (n, m))

    points = np.zeros([len(kr),2])
    points[:,0] = kr
    points[:,1] = kc 

    A = np.reshape(A, [n,m])
    values = A[kr,kc] 

    return griddata(points, values, (grid_x, grid_y), fill_value=1, method = 'linear')

# %% [markdown]
# ## Demosaicizzazione tramite Interpolazione Lineare sul Pattern di Bayer

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error as mse, peak_signal_noise_ratio as psnr

def demosaicing_bayer(image, Red_Inpaint, Green_Inpaint, Blue_Inpaint):
    
    bayer_color = np.empty((image.shape), float)
    bayer_color[:] = np.nan
    
    bayer_color[0::2, 0::2, 0] = Red_Inpaint[0::2, 0::2]   # top left
    bayer_color[0::2, 1::2, 1] = Green_Inpaint[0::2, 1::2] # top right
    bayer_color[1::2, 0::2, 1] = Green_Inpaint[1::2, 0::2] # bottom left
    bayer_color[1::2, 1::2, 2] = Blue_Inpaint[1::2, 1::2]  # bottom right
    
    Glinear = bayer_color.copy().astype(float)

    tic = time.perf_counter()
    
    for i in range(3):
        Glinear[:, :, i] = linear_interpolation(bayer_color[:, :, i], bayer_color.shape[0], bayer_color.shape[1])
        
    toc_linear = time.perf_counter()
    
    linear_process_time = toc_linear - tic

    print('Tempo impiegato per l\'Interpolazione Lineare in secondi:', linear_process_time)
    
    mse_original = mse(image, image)
    ssim_original = ssim(image, image, data_range = image.max() - image.min(), channel_axis=2)
    psnr_original = psnr(image, image)

    mse_linear = mse(image, Glinear)
    ssim_linear = ssim(image, Glinear, data_range = Glinear.max() - Glinear.min(), channel_axis=2)
    psnr_linear = psnr(image, Glinear) 

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 4), sharex=True, sharey=True)
    ax = axes.ravel()

    ax[0].imshow(image.astype(np.uint8))
    ax[0].set_xlabel('MSE: ' + str(round(mse_original, 2)) + '\n' + 'SSIM: ' + str(round(ssim_original, 2)) + 
                     '\n' + 'PSNR: ' + str(round(psnr_original, 2)) )
    ax[0].set_title('Original Image')
    
    ax[1].imshow(Glinear.astype(np.uint8))
    ax[1].set_xlabel('MSE:' + str(round(mse_linear, 2)) + '\n' + 'SSIM: ' + str(round(ssim_linear, 2)) + 
                     '\n' + 'PSNR: ' + str(round(psnr_linear, 2)))
    ax[1].set_title('Linear Interpolation')
    
    plt.imshow(Glinear.astype(np.uint8))
    plt.xlabel('MSE:' + str(round(mse_linear, 2)) + '\n' + 'SSIM: ' + str(round(ssim_linear, 2)) + 
                     '\n' + 'PSNR: ' + str(round(psnr_linear, 2)))
    plt.title('Linear Interpolation')
    
    return linear_process_time, mse_linear, ssim_linear, psnr_linear

# %%
# Bayer Pattern RGGB
def bayer_pattern(image):

    m, n = image[:,:,0].shape # Considero le nuove dimensioni

    Red_Inpaint = np.nan *np.ones(image[:,:,0].shape)
    Red_Inpaint[0:m-1:2, 0:n-1:2] = image[0:m-1:2, 0:n-1:2, 0]

    Green_Inpaint = np.nan *np.ones(image[:,:,1].shape)
    Green_Inpaint[0:m:2, 1:n:2] = image[0:m:2, 1:n:2, 1]
    Green_Inpaint[1:m:2, 0:n-1:2] = image[1:m:2, 0:n-1:2, 1]

    Blue_Inpaint = np.nan *np.ones(image[:,:,2].shape)
    Blue_Inpaint[1:m:2, 1:n:2] = image[1:m:2, 1:n:2, 2]
    
    linear_process_time, mse_linear, ssim_linear, psnr_linear = demosaicing_bayer(image, Red_Inpaint, Green_Inpaint, Blue_Inpaint)
    
    return linear_process_time, mse_linear, ssim_linear, psnr_linear

# %% [markdown]
# ## Riduzione del rumore mediante Interpolazione Lineare

# %%
def denoising_function(image):
    
    m, n = image[:,:,0].shape
    
    G = image.astype(float) 
    G[np.random.rand(*G.shape) < 0.50] = np.nan 

    Glinear = G.copy()
    
    tic = time.perf_counter()

    for i in range(3):
        Glinear[:, :, i] = linear_interpolation(G[:, :, i], m, n)

    toc_linear = time.perf_counter()
    
    linear_process_time = toc_linear - tic

    print('Tempo impiegato per l\'Interpolazione Lineare in secondi:', linear_process_time)
    
    mse_original = mse(image, image)
    ssim_original = ssim(image, image, data_range = image.max() - image.min(), channel_axis=2)
    psnr_original = psnr(image, image)

    mse_linear = mse(image, Glinear)
    ssim_linear = ssim(image, Glinear, data_range = Glinear.max() - Glinear.min(), channel_axis=2)
    psnr_linear = psnr(image, Glinear.astype(np.uint8)) 

#     fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 4), sharex=True, sharey=True)
#     ax = axes.ravel()

#     ax[0].imshow(image.astype(np.uint8))
#     ax[0].set_xlabel('MSE: ' + str(round(mse_original, 2)) + '\n' + 'SSIM: ' + str(round(ssim_original, 2)) + 
#                      '\n' + 'PSNR: ' + str(round(psnr_original, 2)) )
#     ax[0].set_title('Original Image')
    
#     ax[1].imshow(Glinear.astype(np.uint8))
#     ax[1].set_xlabel('MSE:' + str(round(mse_linear, 2)) + '\n' + 'SSIM: ' + str(round(ssim_linear, 2)) + 
#                      '\n' + 'PSNR: ' + str(round(psnr_linear, 2)))
#     ax[1].set_title('Linear Interpolation')
    
    plt.imshow(Glinear.astype(np.uint8))
    plt.xlabel('MSE:' + str(round(mse_linear, 2)) + '\n' + 'SSIM: ' + str(round(ssim_linear, 2)) + 
                     '\n' + 'PSNR: ' + str(round(psnr_linear, 2)))
    plt.title('Denoising-Linear')
    
    return linear_process_time, mse_linear, ssim_linear, psnr_linear

# %% [markdown]
# ## Test e salvataggio dei risultati

# %%
import pandas as pd
import os

def save_results(i, linear_process_time_process_time, mse_linear, ssim_linear, psnr_linear, folder_path):

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    csv_path = os.path.join(folder_path, 'results_linear.csv')

    data = {
        'Image': [i+1],
        'Time Elapsed': [linear_process_time],
        'MSE': [mse_linear],
        'SSIM': [ssim_linear],
        'PSNR': [psnr_linear]
    }

    results = pd.DataFrame(data)

    if os.path.exists(csv_path):
        results.to_csv(csv_path, mode = 'a', header = False, index = False)
    else:
        results.to_csv(csv_path, mode = 'w', header = True, index = False)
        
    plt.savefig(folder_path + '/linear_' + str(i+1) + '.png')

# %% [raw]
# for i in range(len(image_list)):
#     if(i in [3, 8, 9, 16, 17, 18]):
#         continue
#     folder_path = 'results/bayer/linear'
#     linear_process_time, mse_linear, ssim_linear, psnr_linear = bayer_pattern(image_list[i])
#     save_results(i, linear_process_time, mse_linear, ssim_linear, psnr_linear, folder_path)

# %%
for i in range(len(image_list)):
    if(i in [3, 8, 9, 16, 17, 18]):
        continue
    folder_path = 'results/denoising/linear'
    linear_process_time, mse_linear, ssim_linear, psnr_linear = denoising_function(image_list[i])
    save_results(i, linear_process_time, mse_linear, ssim_linear, psnr_linear, folder_path)
# Out:
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.9232899
# C:\Users\Psi\anaconda3\lib\site-packages\skimage\metrics\simple_metrics.py:163: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range ** 2) / err)
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.710180999999999
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.6247701
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.455471800000005
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.4904899
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.421928699999995
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.529021799999995
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.4835444
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.444730000000007
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.454297700000012
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.506233000000009
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.507927499999994
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.562232100000017
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.590183300000007
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.873685200000011
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.40348209999999
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.328369900000013
# Tempo impiegato per l'Interpolazione Lineare in secondi: 12.4671266

# %%
import pandas as pd

df = pd.read_csv('results/denoising/linear/results_linear.csv')

df['Time Elapsed'] = df['Time Elapsed'].astype(float)
df['MSE'] = df['MSE'].astype(float)
df['SSIM'] = df['SSIM'].astype(float)
df['PSNR'] = df['PSNR'].astype(float)

df['Time Elapsed'] = df['Time Elapsed'].round(2)
df['MSE'] = df['MSE'].round(2)
df['SSIM'] = df['SSIM'].round(2)
df['PSNR'] = df['PSNR'].round(2)

df.to_csv('results/denoising/linear/results_linear_trunc.csv', index=False)
